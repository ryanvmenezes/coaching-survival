# %%
import requests
from bs4 import BeautifulSoup

# %%
import csv
import json

# %%
URL = 'https://www.sports-reference.com/cfb/schools/southern-california/'

# %%
r = requests.get(URL)
soup = BeautifulSoup(r.text, "html5lib")

# %%
coaches = soup.find_all(attrs={"data-stat": "coaches"})

# %%
c = coaches[5]

# %%
c
# Out:
# <td class="left " csk="Helton,Clay.2013 Kiffin,Lane.2013 Orgeron,Ed.2013" data-stat="coaches"><a href="/cfb/coaches/clay-helton-1.html">Clay Helton</a> (1-0), <a href="/cfb/coaches/lane-kiffin-1.html">Lane Kiffin</a> (3-2), <a href="/cfb/coaches/ed-orgeron-1.html">Ed Orgeron</a> (6-2)</td>

# %%
list(c.children)
# Out:
# [<a href="/cfb/coaches/clay-helton-1.html">Clay Helton</a>,
#  u' (1-0), ',
#  <a href="/cfb/coaches/lane-kiffin-1.html">Lane Kiffin</a>,
#  u' (3-2), ',
#  <a href="/cfb/coaches/ed-orgeron-1.html">Ed Orgeron</a>,
#  u' (6-2)']

# %%
len(list(c.children))
# Out:
# 6

# %%
c.text
# Out:
# u'Clay Helton (1-0), Lane Kiffin (3-2), Ed Orgeron (6-2)'

# %%
tbl = soup.find("table", "stats_table").tbody.find_all('tr')

# %%
teams = []
with open('sportsref-teams.psv') as csvfile:
    reader = csv.DictReader(csvfile, delimiter='|')
    for row in reader:
        teams.append(row)

# %%
coaches = []
with open('sportsref-coaches.csv') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if int(row['year']) >= 2000 and int(row['year']) < 2017:
            coaches.append(row)

# %%
def parse_coach(string):
    nr = string[:-1].split(" (")
    name = nr[0]
    record = nr[1]
    wl = record.split("-")
    wins = wl[0]
    losses = wl[1]
    
    return name, int(wins), int(losses)

# %%
coaches = []
with open('coaches-ordered-corrected.csv') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        cleaned = {}
        cleaned['team'] = row['team']
        cleaned['season'] = row['year']
        cleaned['coach'] = row['name']
        cleaned['games'] = int(row['total_games'])
        if row['correct_order'] == '':
            cleaned['order'] = int(row['order'])
        else:
            cleaned['order'] = int(row['correct_order'])
        
        coaches.append(cleaned)

# %%
bool("")
# Out:
# False

# %%
coaches_sorted = sorted(coaches, key=lambda x: x['order'])

# %%
coaches_sorted[-10:]
# Out:
# [{'coach': 'DeWayne Walker',
#   'games': 1,
#   'order': 2,
#   'season': '2007',
#   'team': 'ucla'},
#  {'coach': 'Ed Kezirian',
#   'games': 1,
#   'order': 2,
#   'season': '2002',
#   'team': 'ucla'},
#  {'coach': 'Clay Helton',
#   'games': 9,
#   'order': 2,
#   'season': '2015',
#   'team': 'southern-california'},
#  {'coach': 'Ed Orgeron',
#   'games': 8,
#   'order': 2,
#   'season': '2013',
#   'team': 'southern-california'},
#  {'coach': 'Kyle Whittingham',
#   'games': 1,
#   'order': 2,
#   'season': '2004',
#   'team': 'utah'},
#  {'coach': 'Marques Tuiasosopo',
#   'games': 1,
#   'order': 2,
#   'season': '2013',
#   'team': 'washington'},
#  {'coach': 'Bill Stewart',
#   'games': 1,
#   'order': 2,
#   'season': '2007',
#   'team': 'west-virginia'},
#  {'coach': 'Barry Alvarez',
#   'games': 1,
#   'order': 2,
#   'season': '2014',
#   'team': 'wisconsin'},
#  {'coach': 'Barry Alvarez',
#   'games': 1,
#   'order': 2,
#   'season': '2012',
#   'team': 'wisconsin'},
#  {'coach': 'Clay Helton',
#   'games': 1,
#   'order': 3,
#   'season': '2013',
#   'team': 'southern-california'}]

# %%
team_look = {}

# %%
for c in coaches_sorted:
    t = c['team']
    s = c['season']
    g = c['games']
    ch = c['coach']
    if not team_look.get(t):
        team_look[t] = {}
    if not team_look[t].get(s):
        team_look[t][s] = []
    for i in range(0, g):
        team_look[t][s].append(ch)

# %%
class Tenure(object):
    def __init__(self, info):
        self.coach = info['coach']
        self.results = []
        self.currszn = info['season']
        self.seasons = 1
        self.team = info['team']
        self.min_year = info['season']
        self.max_year = info['season']
        self.left_censor = (info['game_num'] == '1') and (info['season'] == '2000')
        self.right_censor = False
    
    def win(self):
        self.results.append(True)
    
    def loss(self):
        self.results.append(False)
    
    def add_szn(self):
        self.seasons += 1
    
    def slugify(self):
        return "{}|{}|{}|{}".format(
            self.coach.lower().split()[-1],
            self.min_year[2:4],
            self.max_year[2:4],
            self.team
        )

# %%
games = []
with open('sportsref-gamelogs.csv') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        row['coach'] = team_look[row['team']][row['season']][int(row['game_num'])-1]
        games.append(row)

# %%
games = sorted(games, key=lambda x: (x['team'], x['date']))

# %%
tenures = []
T = Tenure(games[0])

for gm in games[1:]:
    newcoach = (gm['coach'] != T.coach)
    newteam = (gm['team'] != T.team)
    
    if newcoach or newteam:
        tenures.append(T)
        T = Tenure(gm)
    
    if gm['season'] != T.currszn:
        T.add_szn()
        T.currszn = gm['season']
        T.max_year = gm['season']
    
    if gm['result'] == 'W':
        T.win()
    else:
        T.loss()
        
    if (int(gm['game_num']) == len(team_look[gm['team']][gm['season']])) and (gm['season'] == '2016'):
        T.right_censor = True
        T.max_year = gm['season']
        tenures.append(T)

# %%
[{
    'coach': t.coach,
    'games': len(t.results),
    'wins': sum(t.results),
    'losses': len(t.results) - sum(t.results),
    'currszn': t.currszn,
    'seasons': t.seasons,
    'team': t.team,
    'min_year': t.min_year,
    'max_year': t.max_year,
    'left_censor': t.left_censor,
    'right_censor': t.right_censor,
    'slug': t.slugify()
} for t in tenures]
# Out:
# [{'coach': 'Mike DuBose',
#   'currszn': '2000',
#   'games': 10,
#   'left_censor': True,
#   'losses': 7,
#   'max_year': '',
#   'min_year': '00',
#   'right_censor': False,
#   'seasons': 1,
#   'slug': 'dubose|00||alabama',
#   'team': 'alabama',
#   'wins': 3},
#  {'coach': 'Dennis Franchione',
#   'currszn': '2002',
#   'games': 24,
#   'left_censor': False,
#   'losses': 8,
#   'max_year': '02',
#   'min_year': '01',
#   'right_censor': False,
#   'seasons': 2,
#   'slug': 'franchione|01|02|alabama',
#   'team': 'alabama',
#   'wins': 16},
#  {'coach': 'Mike Shula',
#   'currszn': '2006',
#   'games': 49,
#   'left_censor': False,
#   'losses': 23,
#   'max_year': '06',
#   'min_year': '03',
#   'right_censor': False,
#   'seasons': 4,
#   'slug': 'shula|03|06|alabama',
#   'team': 'alabama',
#   'wins': 26},
#  {'coach': 'Joe Kines',
#   'currszn': '2006',
#   'games': 1,
#   'left_censor': False,
#   'losses': 1,
#   'max_year': '',
#   'min_year': '06',
#   'right_censor': False,
#   'seasons': 1,
#   'slug': 'kines|06||alabama',
#   'team': 'alabama',
#   'wins': 0},
#  {'coach': 'Nick Saban',
#   'currszn': '2016',
#   'games': 138,
#   'left_censor': False,
#   'losses': 19,
#   'max_year': '16',
#   'min_year': '07',
#   'right_censor': True,
#   'seasons': 10,
#   'slug': 'saban|07|16|alabama',
#   'team': 'alabama',
#   'wins': 119},
#  {'coach': 'Nick Saban',
#   'currszn': '2016',
#   'games': 138,
#   'left_censor': False,
#   'losses': 19,
#   'max_year': '16',
#   'min_year': '07',
#   'right_censor': True,
#   'seasons': 10,
#   'slug': 'saban|07|16|alabama',
#   'team': 'alabama',
#   'wins': 119},
#  {'coach': 'Dick Tomey',
#   'currszn': '2000',
#   'games': 11,
#   'left_censor': True,
#   'losses': 6,
#   'max_year': '',
#   'min_year': '00',
#   'right_censor': False,
#   'seasons': 1,
#   'slug': 'tomey|00||arizona',
#   'team': 'arizona',
#   'wins': 5},
#  {'coach': 'John Mackovic',
#   'currszn': '2003',
#   'games': 28,
#   'left_censor': False,
#   'losses': 18,
#   'max_year': '03',
#   'min_year': '01',
#   'right_censor': False,
#   'seasons': 3,
#   'slug': 'mackovic|01|03|arizona',
#   'team': 'arizona',
#   'wins': 10},
#  {'coach': 'Mike Hankwitz',
#   'currszn': '2003',
#   'games': 7,
#   'left_censor': False,
#   'losses': 6,
#   'max_year': '',
#   'min_year': '03',
#   'right_censor': False,
#   'seasons': 1,
#   'slug': 'hankwitz|03||arizona',
#   'team': 'arizona',
#   'wins': 1},
#  {'coach': 'Mike Stoops',
#   'currszn': '2011',
#   'games': 91,
#   'left_censor': False,
#   'losses': 50,
#   'max_year': '11',
#   'min_year': '04',
#   'right_censor': False,
#   'seasons': 8,
#   'slug': 'stoops|04|11|arizona',
#   'team': 'arizona',
#   'wins': 41},
#  {'coach': 'Tim Kish',
#   'currszn': '2011',
#   'games': 6,
#   'left_censor': False,
#   'losses': 3,
#   'max_year': '',
#   'min_year': '11',
#   'right_censor': False,
#   'seasons': 1,
#   'slug': 'kish|11||arizona',
#   'team': 'arizona',
#   'wins': 3},
#  {'coach': 'Rich Rodriguez',
#   'currszn': '2016',
#   'games': 65,
#   'left_censor': False,
#   'losses': 29,
#   'max_year': '16',
#   'min_year': '12',
#   'right_censor': True,
#   'seasons': 5,
#   'slug': 'rodriguez|12|16|arizona',
#   'team': 'arizona',
#   'wins': 36},
#  {'coach': 'Rich Rodriguez',
#   'currszn': '2016',
#   'games': 65,
#   'left_censor': False,
#   'losses': 29,
#   'max_year': '16',
#   'min_year': '12',
#   'right_censor': True,
#   'seasons': 5,
#   'slug': 'rodriguez|12|16|arizona',
#   'team': 'arizona',
#   'wins': 36},
#  {'coach': 'Bruce Snyder',
#   'currszn': '2000',
#   'games': 11,
#   'left_censor': True,
#   'losses': 5,
#   'max_year': '',
#   'min_year': '00',
#   'right_censor': False,
#   'seasons': 1,
#   'slug': 'snyder|00||arizona-state',
#   'team': 'arizona-state',
#   'wins': 6},
#  {'coach': 'Dirk Koetter',
#   'currszn': '2006',
#   'games': 74,
#   'left_censor': False,
#   'losses': 34,
#   'max_year': '06',
#   'min_year': '01',
#   'right_censor': False,
#   'seasons': 6,
#   'slug': 'koetter|01|06|arizona-state',
#   'team': 'arizona-state',
#   'wins': 40},
#  {'coach': 'Dennis Erickson',
#   'currszn': '2011',
#   'games': 62,
#   'left_censor': False,
#   'losses': 31,
#   'max_year': '11',
#   'min_year': '07',
#   'right_censor': False,
#   'seasons': 5,
#   'slug': 'erickson|07|11|arizona-state',
#   'team': 'arizona-state',
#   'wins': 31},
#  {'coach': 'Todd Graham',
#   'currszn': '2016',
#   'games': 65,
#   'left_censor': False,
#   'losses': 26,
#   'max_year': '16',
#   'min_year': '12',
#   'right_censor': True,
#   'seasons': 5,
#   'slug': 'graham|12|16|arizona-state',
#   'team': 'arizona-state',
#   'wins': 39},
#  {'coach': 'Todd Graham',
#   'currszn': '2016',
#   'games': 65,
#   'left_censor': False,
#   'losses': 26,
#   'max_year': '16',
#   'min_year': '12',
#   'right_censor': True,
#   'seasons': 5,
#   'slug': 'graham|12|16|arizona-state',
#   'team': 'arizona-state',
#   'wins': 39},
#  {'coach': 'Houston Nutt',
#   'currszn': '2007',
#   'games': 97,
#   'left_censor': True,
#   'losses': 39,
#   'max_year': '07',
#   'min_year': '00',
#   'right_censor': False,
#   'seasons': 8,
#   'slug': 'nutt|00|07|arkansas',
#   'team': 'arkansas',
#   'wins': 58},
#  {'coach': 'Reggie Herring',
#   'currszn': '2007',
#   'games': 1,
#   'left_censor': False,
#   'losses': 1,
#   'max_year': '',
#   'min_year': '07',
#   'right_censor': False,
#   'seasons': 1,
#   'slug': 'herring|07||arkansas',
#   'team': 'arkansas',
#   'wins': 0},
#  {'coach': 'Bobby Petrino',
#   'currszn': '2011',
#   'games': 51,
#   'left_censor': False,
#   'losses': 17,
#   'max_year': '11',
#   'min_year': '08',
#   'right_censor': False,
#   'seasons': 4,
#   'slug': 'petrino|08|11|arkansas',
#   'team': 'arkansas',
#   'wins': 34},
#  {'coach': 'John Smith',
#   'currszn': '2012',
#   'games': 12,
#   'left_censor': False,
#   'losses': 8,
#   'max_year': '',
#   'min_year': '12',
#   'right_censor': False,
#   'seasons': 1,
#   'slug': 'smith|12||arkansas',
#   'team': 'arkansas',
#   'wins': 4},
#  {'coach': 'Bret Bielema',
#   'currszn': '2016',
#   'games': 51,
#   'left_censor': False,
#   'losses': 26,
#   'max_year': '16',
#   'min_year': '13',
#   'right_censor': True,
#   'seasons': 4,
#   'slug': 'bielema|13|16|arkansas',
#   'team': 'arkansas',
#   'wins': 25},
#  {'coach': 'Bret Bielema',
#   'currszn': '2016',
#   'games': 51,
#   'left_censor': False,
#   'losses': 26,
#   'max_year': '16',
#   'min_year': '13',
#   'right_censor': True,
#   'seasons': 4,
#   'slug': 'bielema|13|16|arkansas',
#   'team': 'arkansas',
#   'wins': 25},
#  {'coach': 'Tommy Tuberville',
#   'currszn': '2008',
#   'games': 112,
#   'left_censor': True,
#   'losses': 32,
#   'max_year': '08',
#   'min_year': '00',
#   'right_censor': False,
#   'seasons': 9,
#   'slug': 'tuberville|00|08|auburn',
#   'team': 'auburn',
#   'wins': 80},
#  {'coach': 'Gene Chizik',
#   'currszn': '2012',
#   'games': 52,
#   'left_censor': False,
#   'losses': 19,
#   'max_year': '12',
#   'min_year': '09',
#   'right_censor': False,
#   'seasons': 4,
#   'slug': 'chizik|09|12|auburn',
#   'team': 'auburn',
#   'wins': 33},
#  {'coach': 'Gus Malzahn',
#   'currszn': '2016',
#   'games': 53,
#   'left_censor': False,
#   'losses': 18,
#   'max_year': '16',
#   'min_year': '13',
#   'right_censor': True,
#   'seasons': 4,
#   'slug': 'malzahn|13|16|auburn',
#   'team': 'auburn',
#   'wins': 35},
#  {'coach': 'Gus Malzahn',
#   'currszn': '2016',
#   'games': 53,
#   'left_censor': False,
#   'losses': 18,
#   'max_year': '16',
#   'min_year': '13',
#   'right_censor': True,
#   'seasons': 4,
#   'slug': 'malzahn|13|16|auburn',
#   'team': 'auburn',
#   'wins': 35},
#  {'coach': 'Kevin Steele',
#   'currszn': '2002',
#   'games': 34,
#   'left_censor': True,
#   'losses': 26,
#   'max_year': '02',
#   'min_year': '00',
#   'right_censor': False,
#   'seasons': 3,
#   'slug': 'steele|00|02|baylor',
#   'team': 'baylor',
#   'wins': 8},
#  {'coach': 'Guy Morriss',
#   'currszn': '2007',
#   'games': 58,
#   'left_censor': False,
#   'losses': 40,
#   'max_year': '07',
#   'min_year': '03',
#   'right_censor': False,
#   'seasons': 5,
#   'slug': 'morriss|03|07|baylor',
#   'team': 'baylor',
#   'wins': 18},
#  {'coach': 'Art Briles',
#   'currszn': '2015',
#   'games': 102,
#   'left_censor': False,
#   'losses': 37,
#   'max_year': '15',
#   'min_year': '08',
#   'right_censor': False,
#   'seasons': 8,
#   'slug': 'briles|08|15|baylor',
#   'team': 'baylor',
#   'wins': 65},
#  {'coach': 'Jim Grobe',
#   'currszn': '2016',
#   'games': 13,
#   'left_censor': False,
#   'losses': 6,
#   'max_year': '16',
#   'min_year': '16',
#   'right_censor': True,
#   'seasons': 1,
#   'slug': 'grobe|16|16|baylor',
#   'team': 'baylor',
#   'wins': 7},
#  {'coach': 'Jim Grobe',
#   'currszn': '2016',
#   'games': 13,
#   'left_censor': False,
#   'losses': 6,
#   'max_year': '16',
#   'min_year': '16',
#   'right_censor': True,
#   'seasons': 1,
#   'slug': 'grobe|16|16|baylor',
#   'team': 'baylor',
#   'wins': 7},
#  {'coach': "Tom O'Brien",
#   'currszn': '2006',
#   'games': 84,
#   'left_censor': True,
#   'losses': 27,
#   'max_year': '06',
#   'min_year': '00',
#   'right_censor': False,
#   'seasons': 7,
#   'slug': "o'brien|00|06|boston-college",
#   'team': 'boston-college',
#   'wins': 57},
#  {'coach': 'Frank Spaziani',
#   'currszn': '2006',
#   'games': 1,
#   'left_censor': False,
#   'losses': 0,
#   'max_year': '',
#   'min_year': '06',
#   'right_censor': False,
#   'seasons': 1,
#   'slug': 'spaziani|06||boston-college',
#   'team': 'boston-college',
#   'wins': 1},
#  {'coach': 'Jeff Jagodzinski',
#   'currszn': '2008',
#   'games': 28,
#   'left_censor': False,
#   'losses': 8,
#   'max_year': '08',
#   'min_year': '07',
#   'right_censor': False,
#   'seasons': 2,
#   'slug': 'jagodzinski|07|08|boston-college',
#   'team': 'boston-college',
#   'wins': 20},
#  {'coach': 'Frank Spaziani',
#   'currszn': '2012',
#   'games': 50,
#   'left_censor': False,
#   'losses': 29,
#   'max_year': '12',
#   'min_year': '09',
#   'right_censor': False,
#   'seasons': 4,
#   'slug': 'spaziani|09|12|boston-college',
#   'team': 'boston-college',
#   'wins': 21},
#  {'coach': 'Steve Addazio',
#   'currszn': '2016',
#   'games': 51,
#   'left_censor': False,
#   'losses': 27,
#   'max_year': '16',
#   'min_year': '13',
#   'right_censor': True,
#   'seasons': 4,
#   'slug': 'addazio|13|16|boston-college',
#   'team': 'boston-college',
#   'wins': 24},
#  {'coach': 'Steve Addazio',
#   'currszn': '2016',
#   'games': 51,
#   'left_censor': False,
#   'losses': 27,
#   'max_year': '16',
#   'min_year': '13',
#   'right_censor': True,
#   'seasons': 4,
#   'slug': 'addazio|13|16|boston-college',
#   'team': 'boston-college',
#   'wins': 24},
#  {'coach': 'Tom Holmoe',
#   'currszn': '2001',
#   'games': 22,
#   'left_censor': True,
#   'losses': 18,
#   'max_year': '01',
#   'min_year': '00',
#   'right_censor': False,
#   'seasons': 2,
#   'slug': 'holmoe|00|01|california',
#   'team': 'california',
#   'wins': 4},
#  {'coach': 'Jeff Tedford',
#   'currszn': '2012',
#   'games': 139,
#   'left_censor': False,
#   'losses': 57,
#   'max_year': '12',
#   'min_year': '02',
#   'right_censor': False,
#   'seasons': 11,
#   'slug': 'tedford|02|12|california',
#   'team': 'california',
#   'wins': 82},
#  {'coach': 'Sonny Dykes',
#   'currszn': '2016',
#   'games': 49,
#   'left_censor': False,
#   'losses': 30,
#   'max_year': '16',
#   'min_year': '13',
#   'right_censor': True,
#   'seasons': 4,
#   'slug': 'dykes|13|16|california',
#   'team': 'california',
#   'wins': 19},
#  {'coach': 'Sonny Dykes',
#   'currszn': '2016',
#   'games': 49,
#   'left_censor': False,
#   'losses': 30,
#   'max_year': '16',
#   'min_year': '13',
#   'right_censor': True,
#   'seasons': 4,
#   'slug': 'dykes|13|16|california',
#   'team': 'california',
#   'wins': 19},
#  {'coach': 'Tommy Bowden',
#   'currszn': '2008',
#   'games': 103,
#   'left_censor': True,
#   'losses': 38,
#   'max_year': '08',
#   'min_year': '00',
#   'right_censor': False,
#   'seasons': 9,
#   'slug': 'bowden|00|08|clemson',
#   'team': 'clemson',
#   'wins': 65},
#  {'coach': 'Dabo Swinney',
#   'currszn': '2016',
#   'games': 117,
#   'left_censor': False,
#   'losses': 28,
#   'max_year': '16',
#   'min_year': '08',
#   'right_censor': True,
#   'seasons': 9,
#   'slug': 'swinney|08|16|clemson',
#   'team': 'clemson',
#   'wins': 89},
#  {'coach': 'Dabo Swinney',
#   'currszn': '2016',
#   'games': 117,
#   'left_censor': False,
#   'losses': 28,
#   'max_year': '16',
#   'min_year': '08',
#   'right_censor': True,
#   'seasons': 9,
#   'slug': 'swinney|08|16|clemson',
#   'team': 'clemson',
#   'wins': 89},
#  {'coach': 'Gary Barnett',
#   'currszn': '2005',
#   'games': 74,
#   'left_censor': True,
#   'losses': 32,
#   'max_year': '05',
#   'min_year': '00',
#   'right_censor': False,
#   'seasons': 6,
#   'slug': 'barnett|00|05|colorado',
#   'team': 'colorado',
#   'wins': 42},
#  {'coach': 'Mike Hankwitz',
#   'currszn': '2005',
#   'games': 1,
#   'left_censor': False,
#   'losses': 1,
#   'max_year': '',
#   'min_year': '05',
#   'right_censor': False,
#   'seasons': 1,
#   'slug': 'hankwitz|05||colorado',
#   'team': 'colorado',
#   'wins': 0},
#  {'coach': 'Dan Hawkins',
#   'currszn': '2010',
#   'games': 58,
#   'left_censor': False,
#   'losses': 39,
#   'max_year': '10',
#   'min_year': '06',
#   'right_censor': False,
#   'seasons': 5,
#   'slug': 'hawkins|06|10|colorado',
#   'team': 'colorado',
#   'wins': 19},
#  {'coach': 'Brian Cabral',
#   'currszn': '2010',
#   'games': 3,
#   'left_censor': False,
#   'losses': 1,
#   'max_year': '',
#   'min_year': '10',
#   'right_censor': False,
#   'seasons': 1,
#   'slug': 'cabral|10||colorado',
#   'team': 'colorado',
#   'wins': 2},
#  {'coach': 'Jon Embree',
#   'currszn': '2012',
#   'games': 25,
#   'left_censor': False,
#   'losses': 21,
#   'max_year': '12',
#   'min_year': '11',
#   'right_censor': False,
#   'seasons': 2,
#   'slug': 'embree|11|12|colorado',
#   'team': 'colorado',
#   'wins': 4},
#  {'coach': 'Mike MacIntyre',
#   'currszn': '2016',
#   'games': 50,
#   'left_censor': False,
#   'losses': 31,
#   'max_year': '16',
#   'min_year': '13',
#   'right_censor': True,
#   'seasons': 4,
#   'slug': 'macintyre|13|16|colorado',
#   'team': 'colorado',
#   'wins': 19},
#  {'coach': 'Mike MacIntyre',
#   'currszn': '2016',
#   'games': 50,
#   'left_censor': False,
#   'losses': 31,
#   'max_year': '16',
#   'min_year': '13',
#   'right_censor': True,
#   'seasons': 4,
#   'slug': 'macintyre|13|16|colorado',
#   'team': 'colorado',
#   'wins': 19},
#  {'coach': 'Carl Franks',
#   'currszn': '2003',
#   'games': 46,
#   'left_censor': True,
#   'losses': 40,
#   'max_year': '03',
#   'min_year': '00',
#   'right_censor': False,
#   'seasons': 4,
#   'slug': 'franks|00|03|duke',
#   'team': 'duke',
#   'wins': 6},
#  {'coach': 'Ted Roof',
#   'currszn': '2007',
#   'games': 46,
#   'left_censor': False,
#   'losses': 42,
#   'max_year': '07',
#   'min_year': '04',
#   'right_censor': False,
#   'seasons': 4,
#   'slug': 'roof|04|07|duke',
#   'team': 'duke',
#   'wins': 4},
#  {'coach': 'David Cutcliffe',
#   'currszn': '2016',
#   'games': 113,
#   'left_censor': False,
#   'losses': 61,
#   'max_year': '16',
#   'min_year': '08',
#   'right_censor': True,
#   'seasons': 9,
#   'slug': 'cutcliffe|08|16|duke',
#   'team': 'duke',
#   'wins': 52},
#  {'coach': 'David Cutcliffe',
#   'currszn': '2016',
#   'games': 113,
#   'left_censor': False,
#   'losses': 61,
#   'max_year': '16',
#   'min_year': '08',
#   'right_censor': True,
#   'seasons': 9,
#   'slug': 'cutcliffe|08|16|duke',
#   'team': 'duke',
#   'wins': 52},
#  {'coach': 'Steve Spurrier',
#   'currszn': '2001',
#   'games': 23,
#   'left_censor': True,
#   'losses': 4,
#   'max_year': '01',
#   'min_year': '00',
#   'right_censor': False,
#   'seasons': 2,
#   'slug': 'spurrier|00|01|florida',
#   'team': 'florida',
#   'wins': 19},
#  {'coach': 'Ron Zook',
#   'currszn': '2004',
#   'games': 37,
#   'left_censor': False,
#   'losses': 14,
#   'max_year': '04',
#   'min_year': '02',
#   'right_censor': False,
#   'seasons': 3,
#   'slug': 'zook|02|04|florida',
#   'team': 'florida',
#   'wins': 23},
#  {'coach': 'Charlie Strong',
#   'currszn': '2004',
#   'games': 1,
#   'left_censor': False,
#   'losses': 1,
#   'max_year': '',
#   'min_year': '04',
#   'right_censor': False,
#   'seasons': 1,
#   'slug': 'strong|04||florida',
#   'team': 'florida',
#   'wins': 0},
#  {'coach': 'Urban Meyer',
#   'currszn': '2010',
#   'games': 80,
#   'left_censor': False,
#   'losses': 15,
#   'max_year': '10',
#   'min_year': '05',
#   'right_censor': False,
#   'seasons': 6,
#   'slug': 'meyer|05|10|florida',
#   'team': 'florida',
#   'wins': 65},
#  {'coach': 'Will Muschamp',
#   'currszn': '2014',
#   'games': 49,
#   'left_censor': False,
#   'losses': 21,
#   'max_year': '14',
#   'min_year': '11',
#   'right_censor': False,
#   'seasons': 4,
#   'slug': 'muschamp|11|14|florida',
#   'team': 'florida',
#   'wins': 28},
#  {'coach': 'D.J. Durkin',
#   'currszn': '2014',
#   'games': 1,
#   'left_censor': False,
#   'losses': 0,
#   'max_year': '',
#   'min_year': '14',
#   'right_censor': False,
#   'seasons': 1,
#   'slug': 'durkin|14||florida',
#   'team': 'florida',
#   'wins': 1},
#  {'coach': 'Jim McElwain',
#   'currszn': '2016',
#   'games': 27,
#   'left_censor': False,
#   'losses': 8,
#   'max_year': '16',
#   'min_year': '15',
#   'right_censor': True,
#   'seasons': 2,
#   'slug': 'mcelwain|15|16|florida',
#   'team': 'florida',
#   'wins': 19},
#  {'coach': 'Jim McElwain',
#   'currszn': '2016',
#   'games': 27,
#   'left_censor': False,
#   'losses': 8,
#   'max_year': '16',
#   'min_year': '15',
#   'right_censor': True,
#   'seasons': 2,
#   'slug': 'mcelwain|15|16|florida',
#   'team': 'florida',
#   'wins': 19},
#  {'coach': 'Bobby Bowden',
#   'currszn': '2009',
#   'games': 127,
#   'left_censor': True,
#   'losses': 43,
#   'max_year': '09',
#   'min_year': '00',
#   'right_censor': False,
#   'seasons': 10,
#   'slug': 'bowden|00|09|florida-state',
#   'team': 'florida-state',
#   'wins': 84},
#  {'coach': 'Jimbo Fisher',
#   'currszn': '2016',
#   'games': 95,
#   'left_censor': False,
#   'losses': 17,
#   'max_year': '16',
#   'min_year': '10',
#   'right_censor': True,
#   'seasons': 7,
#   'slug': 'fisher|10|16|florida-state',
#   'team': 'florida-state',
#   'wins': 78},
#  {'coach': 'Jimbo Fisher',
#   'currszn': '2016',
#   'games': 95,
#   'left_censor': False,
#   'losses': 17,
#   'max_year': '16',
#   'min_year': '10',
#   'right_censor': True,
#   'seasons': 7,
#   'slug': 'fisher|10|16|florida-state',
#   'team': 'florida-state',
#   'wins': 78},
#  {'coach': 'Jim Donnan',
#   'currszn': '2000',
#   'games': 11,
#   'left_censor': True,
#   'losses': 4,
#   'max_year': '',
#   'min_year': '00',
#   'right_censor': False,
#   'seasons': 1,
#   'slug': 'donnan|00||georgia',
#   'team': 'georgia',
#   'wins': 7},
#  {'coach': 'Mark Richt',
#   'currszn': '2015',
#   'games': 194,
#   'left_censor': False,
#   'losses': 50,
#   'max_year': '15',
#   'min_year': '01',
#   'right_censor': False,
#   'seasons': 15,
#   'slug': 'richt|01|15|georgia',
#   'team': 'georgia',
#   'wins': 144},
#  {'coach': 'Bryan McClendon',
#   'currszn': '2015',
#   'games': 1,
#   'left_censor': False,
#   'losses': 0,
#   'max_year': '',
#   'min_year': '15',
#   'right_censor': False,
#   'seasons': 1,
#   'slug': 'mcclendon|15||georgia',
#   'team': 'georgia',
#   'wins': 1},
#  {'coach': 'Kirby Smart',
#   'currszn': '2016',
#   'games': 13,
#   'left_censor': False,
#   'losses': 5,
#   'max_year': '16',
#   'min_year': '16',
#   'right_censor': True,
#   'seasons': 1,
#   'slug': 'smart|16|16|georgia',
#   'team': 'georgia',
#   'wins': 8},
#  {'coach': 'Kirby Smart',
#   'currszn': '2016',
#   'games': 13,
#   'left_censor': False,
#   'losses': 5,
#   'max_year': '16',
#   'min_year': '16',
#   'right_censor': True,
#   'seasons': 1,
#   'slug': 'smart|16|16|georgia',
#   'team': 'georgia',
#   'wins': 8},
#  {'coach': "George O'Leary",
#   'currszn': '2001',
#   'games': 23,
#   'left_censor': True,
#   'losses': 7,
#   'max_year': '01',
#   'min_year': '00',
#   'right_censor': False,
#   'seasons': 2,
#   'slug': "o'leary|00|01|georgia-tech",
#   'team': 'georgia-tech',
#   'wins': 16},
#  {'coach': 'Chan Gailey',
#   'currszn': '2007',
#   'games': 76,
#   'left_censor': False,
#   'losses': 32,
#   'max_year': '07',
#   'min_year': '02',
#   'right_censor': False,
#   'seasons': 6,
#   'slug': 'gailey|02|07|georgia-tech',
#   'team': 'georgia-tech',
#   'wins': 44},
#  {'coach': 'Jon Tenuta',
#   'currszn': '2007',
#   'games': 1,
#   'left_censor': False,
#   'losses': 1,
#   'max_year': '',
#   'min_year': '07',
#   'right_censor': False,
#   'seasons': 1,
#   'slug': 'tenuta|07||georgia-tech',
#   'team': 'georgia-tech',
#   'wins': 0},
#  {'coach': 'Paul Johnson',
#   'currszn': '2016',
#   'games': 119,
#   'left_censor': False,
#   'losses': 48,
#   'max_year': '16',
#   'min_year': '08',
#   'right_censor': True,
#   'seasons': 9,
#   'slug': 'johnson|08|16|georgia-tech',
#   'team': 'georgia-tech',
#   'wins': 71},
#  {'coach': 'Paul Johnson',
#   'currszn': '2016',
#   'games': 119,
#   'left_censor': False,
#   'losses': 48,
#   'max_year': '16',
#   'min_year': '08',
#   'right_censor': True,
#   'seasons': 9,
#   'slug': 'johnson|08|16|georgia-tech',
#   'team': 'georgia-tech',
#   'wins': 71},
#  {'coach': 'Ron Turner',
#   'currszn': '2004',
#   'games': 57,
#   'left_censor': True,
#   'losses': 33,
#   'max_year': '04',
#   'min_year': '00',
#   'right_censor': False,
#   'seasons': 5,
#   'slug': 'turner|00|04|illinois',
#   'team': 'illinois',
#   'wins': 24},
#  {'coach': 'Ron Zook',
#   'currszn': '2011',
#   'games': 85,
#   'left_censor': False,
#   'losses': 51,
#   'max_year': '11',
#   'min_year': '05',
#   'right_censor': False,
#   'seasons': 7,
#   'slug': 'zook|05|11|illinois',
#   'team': 'illinois',
#   'wins': 34},
#  {'coach': 'Vic Koenning',
#   'currszn': '2011',
#   'games': 1,
#   'left_censor': False,
#   'losses': 0,
#   'max_year': '',
#   'min_year': '11',
#   'right_censor': False,
#   'seasons': 1,
#   'slug': 'koenning|11||illinois',
#   'team': 'illinois',
#   'wins': 1},
#  {'coach': 'Tim Beckman',
#   'currszn': '2014',
#   'games': 37,
#   'left_censor': False,
#   'losses': 25,
#   'max_year': '14',
#   'min_year': '12',
#   'right_censor': False,
#   'seasons': 3,
#   'slug': 'beckman|12|14|illinois',
#   'team': 'illinois',
#   'wins': 12},
#  {'coach': 'Bill Cubit',
#   'currszn': '2015',
#   'games': 12,
#   'left_censor': False,
#   'losses': 7,
#   'max_year': '',
#   'min_year': '15',
#   'right_censor': False,
#   'seasons': 1,
#   'slug': 'cubit|15||illinois',
#   'team': 'illinois',
#   'wins': 5},
#  {'coach': 'Lovie Smith',
#   'currszn': '2016',
#   'games': 12,
#   'left_censor': False,
#   'losses': 9,
#   'max_year': '16',
#   'min_year': '16',
#   'right_censor': True,
#   'seasons': 1,
#   'slug': 'smith|16|16|illinois',
#   'team': 'illinois',
#   'wins': 3},
#  {'coach': 'Lovie Smith',
#   'currszn': '2016',
#   'games': 12,
#   'left_censor': False,
#   'losses': 9,
#   'max_year': '16',
#   'min_year': '16',
#   'right_censor': True,
#   'seasons': 1,
#   'slug': 'smith|16|16|illinois',
#   'team': 'illinois',
#   'wins': 3},
#  {'coach': 'Cam Cameron',
#   'currszn': '2001',
#   'games': 22,
#   'left_censor': True,
#   'losses': 14,
#   'max_year': '01',
#   'min_year': '00',
#   'right_censor': False,
#   'seasons': 2,
#   'slug': 'cameron|00|01|indiana',
#   'team': 'indiana',
#   'wins': 8},
#  {'coach': 'Gerry DiNardo',
#   'currszn': '2004',
#   'games': 35,
#   'left_censor': False,
#   'losses': 27,
#   'max_year': '04',
#   'min_year': '02',
#   'right_censor': False,
#   'seasons': 3,
#   'slug': 'dinardo|02|04|indiana',
#   'team': 'indiana',
#   'wins': 8},
#  {'coach': 'Terry Hoeppner',
#   'currszn': '2006',
#   'games': 23,
#   'left_censor': False,
#   'losses': 14,
#   'max_year': '06',
#   'min_year': '05',
#   'right_censor': False,
#   'seasons': 2,
#   'slug': 'hoeppner|05|06|indiana',
#   'team': 'indiana',
#   'wins': 9},
#  {'coach': 'Bill Lynch',
#   'currszn': '2010',
#   'games': 49,
#   'left_censor': False,
#   'losses': 30,
#   'max_year': '10',
#   'min_year': '07',
#   'right_censor': False,
#   'seasons': 4,
#   'slug': 'lynch|07|10|indiana',
#   'team': 'indiana',
#   'wins': 19},
#  {'coach': 'Kevin Wilson',
#   'currszn': '2016',
#   'games': 73,
#   'left_censor': False,
#   'losses': 47,
#   'max_year': '16',
#   'min_year': '11',
#   'right_censor': False,
#   'seasons': 6,
#   'slug': 'wilson|11|16|indiana',
#   'team': 'indiana',
#   'wins': 26},
#  {'coach': 'Tom Allen',
#   'currszn': '2016',
#   'games': 1,
#   'left_censor': False,
#   'losses': 1,
#   'max_year': '16',
#   'min_year': '16',
#   'right_censor': True,
#   'seasons': 1,
#   'slug': 'allen|16|16|indiana',
#   'team': 'indiana',
#   'wins': 0},
#  {'coach': 'Tom Allen',
#   'currszn': '2016',
#   'games': 1,
#   'left_censor': False,
#   'losses': 1,
#   'max_year': '16',
#   'min_year': '16',
#   'right_censor': True,
#   'seasons': 1,
#   'slug': 'allen|16|16|indiana',
#   'team': 'indiana',
#   'wins': 0},
#  {'coach': 'Kirk Ferentz',
#   'currszn': '2016',
#   'games': 215,
#   'left_censor': True,
#   'losses': 82,
#   'max_year': '16',
#   'min_year': '00',
#   'right_censor': True,
#   'seasons': 17,
#   'slug': 'ferentz|00|16|iowa',
#   'team': 'iowa',
#   'wins': 133},
#  {'coach': 'Kirk Ferentz',
#   'currszn': '2016',
#   'games': 215,
#   'left_censor': True,
#   'losses': 82,
#   'max_year': '16',
#   'min_year': '00',
#   'right_censor': True,
#   'seasons': 17,
#   'slug': 'ferentz|00|16|iowa',
#   'team': 'iowa',
#   'wins': 133},
#  {'coach': 'Dan McCarney',
#   'currszn': '2006',
#   'games': 84,
#   'left_censor': True,
#   'losses': 42,
#   'max_year': '06',
#   'min_year': '00',
#   'right_censor': False,
#   'seasons': 7,
#   'slug': 'mccarney|00|06|iowa-state',
#   'team': 'iowa-state',
#   'wins': 42},
#  {'coach': 'Gene Chizik',
#   'currszn': '2008',
#   'games': 24,
#   'left_censor': False,
#   'losses': 19,
#   'max_year': '08',
#   'min_year': '07',
#   'right_censor': False,
#   'seasons': 2,
#   'slug': 'chizik|07|08|iowa-state',
#   'team': 'iowa-state',
#   'wins': 5},
#  {'coach': 'Paul Rhoads',
#   'currszn': '2015',
#   'games': 87,
#   'left_censor': False,
#   'losses': 55,
#   'max_year': '15',
#   'min_year': '09',
#   'right_censor': False,
#   'seasons': 7,
#   'slug': 'rhoads|09|15|iowa-state',
#   'team': 'iowa-state',
#   'wins': 32},
#  {'coach': 'Matt Campbell',
#   'currszn': '2016',
#   'games': 12,
#   'left_censor': False,
#   'losses': 9,
#   'max_year': '16',
#   'min_year': '16',
#   'right_censor': True,
#   'seasons': 1,
#   'slug': 'campbell|16|16|iowa-state',
#   'team': 'iowa-state',
#   'wins': 3},
#  {'coach': 'Matt Campbell',
#   'currszn': '2016',
#   'games': 12,
#   'left_censor': False,
#   'losses': 9,
#   'max_year': '16',
#   'min_year': '16',
#   'right_censor': True,
#   'seasons': 1,
#   'slug': 'campbell|16|16|iowa-state',
#   'team': 'iowa-state',
#   'wins': 3},
#  {'coach': 'Terry Allen',
#   'currszn': '2001',
#   'games': 19,
#   'left_censor': True,
#   'losses': 13,
#   'max_year': '01',
#   'min_year': '00',
#   'right_censor': False,
#   'seasons': 2,
#   'slug': 'allen|00|01|kansas',
#   'team': 'kansas',
#   'wins': 6},
#  {'coach': 'Tom Hayes',
#   'currszn': '2001',
#   'games': 3,
#   'left_censor': False,
#   'losses': 2,
#   'max_year': '',
#   'min_year': '01',
#   'right_censor': False,
#   'seasons': 1,
#   'slug': 'hayes|01||kansas',
#   'team': 'kansas',
#   'wins': 1},
#  {'coach': 'Mark Mangino',
#   'currszn': '2009',
#   'games': 98,
#   'left_censor': False,
#   'losses': 48,
#   'max_year': '09',
#   'min_year': '02',
#   'right_censor': False,
#   'seasons': 8,
#   'slug': 'mangino|02|09|kansas',
#   'team': 'kansas',
#   'wins': 50},
#  {'coach': 'Turner Gill',
#   'currszn': '2011',
#   'games': 24,
#   'left_censor': False,
#   'losses': 19,
#   'max_year': '11',
#   'min_year': '10',
#   'right_censor': False,
#   'seasons': 2,
#   'slug': 'gill|10|11|kansas',
#   'team': 'kansas',
#   'wins': 5},
#  {'coach': 'Charlie Weis',
#   'currszn': '2014',
#   'games': 28,
#   'left_censor': False,
#   'losses': 22,
#   'max_year': '14',
#   'min_year': '12',
#   'right_censor': False,
#   'seasons': 3,
#   'slug': 'weis|12|14|kansas',
#   'team': 'kansas',
#   'wins': 6},
#  {'coach': 'Clint Bowen',
#   'currszn': '2014',
#   'games': 8,
#   'left_censor': False,
#   'losses': 7,
#   'max_year': '',
#   'min_year': '14',
#   'right_censor': False,
#   'seasons': 1,
#   'slug': 'bowen|14||kansas',
#   'team': 'kansas',
#   'wins': 1},
#  {'coach': 'David Beaty',
#   'currszn': '2016',
#   'games': 24,
#   'left_censor': False,
#   'losses': 22,
#   'max_year': '16',
#   'min_year': '15',
#   'right_censor': True,
#   'seasons': 2,
#   'slug': 'beaty|15|16|kansas',
#   'team': 'kansas',
#   'wins': 2},
#  {'coach': 'David Beaty',
#   'currszn': '2016',
#   'games': 24,
#   'left_censor': False,
#   'losses': 22,
#   'max_year': '16',
#   'min_year': '15',
#   'right_censor': True,
#   'seasons': 2,
#   'slug': 'beaty|15|16|kansas',
#   'team': 'kansas',
#   'wins': 2},
#  {'coach': 'Bill Snyder',
#   'currszn': '2005',
#   'games': 74,
#   'left_censor': True,
#   'losses': 27,
#   'max_year': '05',
#   'min_year': '00',
#   'right_censor': False,
#   'seasons': 6,
#   'slug': 'snyder|00|05|kansas-state',
#   'team': 'kansas-state',
#   'wins': 47},
#  {'coach': 'Ron Prince',
#   'currszn': '2008',
#   'games': 37,
#   'left_censor': False,
#   'losses': 20,
#   'max_year': '08',
#   'min_year': '06',
#   'right_censor': False,
#   'seasons': 3,
#   'slug': 'prince|06|08|kansas-state',
#   'team': 'kansas-state',
#   'wins': 17},
#  {'coach': 'Bill Snyder',
#   'currszn': '2016',
#   'games': 103,
#   'left_censor': False,
#   'losses': 37,
#   'max_year': '16',
#   'min_year': '09',
#   'right_censor': True,
#   'seasons': 8,
#   'slug': 'snyder|09|16|kansas-state',
#   'team': 'kansas-state',
#   'wins': 66},
#  {'coach': 'Bill Snyder',
#   'currszn': '2016',
#   'games': 103,
#   'left_censor': False,
#   'losses': 37,
#   'max_year': '16',
#   'min_year': '09',
#   'right_censor': True,
#   'seasons': 8,
#   'slug': 'snyder|09|16|kansas-state',
#   'team': 'kansas-state',
#   'wins': 66},
#  {'coach': 'Hal Mumme',
#   'currszn': '2000',
#   'games': 11,
#   'left_censor': True,
#   'losses': 9,
#   'max_year': '',
#   'min_year': '00',
#   'right_censor': False,
#   'seasons': 1,
#   'slug': 'mumme|00||kentucky',
#   'team': 'kentucky',
#   'wins': 2},
#  {'coach': 'Guy Morriss',
#   'currszn': '2002',
#   'games': 23,
#   'left_censor': False,
#   'losses': 14,
#   'max_year': '02',
#   'min_year': '01',
#   'right_censor': False,
#   'seasons': 2,
#   'slug': 'morriss|01|02|kentucky',
#   'team': 'kentucky',
#   'wins': 9},
#  {'coach': 'Rich Brooks',
#   'currszn': '2009',
#   'games': 86,
#   'left_censor': False,
#   'losses': 47,
#   'max_year': '09',
#   'min_year': '03',
#   'right_censor': False,
#   'seasons': 7,
#   'slug': 'brooks|03|09|kentucky',
#   'team': 'kentucky',
#   'wins': 39},
#  {'coach': 'Joker Phillips',
#   'currszn': '2012',
#   'games': 37,
#   'left_censor': False,
#   'losses': 24,
#   'max_year': '12',
#   'min_year': '10',
#   'right_censor': False,
#   'seasons': 3,
#   'slug': 'phillips|10|12|kentucky',
#   'team': 'kentucky',
#   'wins': 13},
#  {'coach': 'Mark Stoops',
#   'currszn': '2016',
#   'games': 49,
#   'left_censor': False,
#   'losses': 30,
#   'max_year': '16',
#   'min_year': '13',
#   'right_censor': True,
#   'seasons': 4,
#   'slug': 'stoops|13|16|kentucky',
#   'team': 'kentucky',
#   'wins': 19},
#  {'coach': 'Mark Stoops',
#   'currszn': '2016',
#   'games': 49,
#   'left_censor': False,
#   'losses': 30,
#   'max_year': '16',
#   'min_year': '13',
#   'right_censor': True,
#   'seasons': 4,
#   'slug': 'stoops|13|16|kentucky',
#   'team': 'kentucky',
#   'wins': 19},
#  {'coach': 'Nick Saban',
#   'currszn': '2004',
#   'games': 62,
#   'left_censor': True,
#   'losses': 16,
#   'max_year': '04',
#   'min_year': '00',
#   'right_censor': False,
#   'seasons': 5,
#   'slug': 'saban|00|04|louisiana-state',
#   'team': 'louisiana-state',
#   'wins': 46},
#  {'coach': 'Les Miles',
#   'currszn': '2016',
#   'games': 148,
#   'left_censor': False,
#   'losses': 34,
#   'max_year': '16',
#   'min_year': '05',
#   'right_censor': False,
#   'seasons': 12,
#   'slug': 'miles|05|16|louisiana-state',
#   'team': 'louisiana-state',
#   'wins': 114},
#  {'coach': 'Ed Orgeron',
#   'currszn': '2016',
#   'games': 8,
#   'left_censor': False,
#   'losses': 2,
#   'max_year': '16',
#   'min_year': '16',
#   'right_censor': True,
#   'seasons': 1,
#   'slug': 'orgeron|16|16|louisiana-state',
#   'team': 'louisiana-state',
#   'wins': 6},
#  {'coach': 'Ed Orgeron',
#   'currszn': '2016',
#   'games': 8,
#   'left_censor': False,
#   'losses': 2,
#   'max_year': '16',
#   'min_year': '16',
#   'right_censor': True,
#   'seasons': 1,
#   'slug': 'orgeron|16|16|louisiana-state',
#   'team': 'louisiana-state',
#   'wins': 6},
#  {'coach': 'John Smith',
#   'currszn': '2002',
#   'games': 36,
#   'left_censor': True,
#   'losses': 10,
#   'max_year': '02',
#   'min_year': '00',
#   'right_censor': False,
#   'seasons': 3,
#   'slug': 'smith|00|02|louisville',
#   'team': 'louisville',
#   'wins': 26},
#  {'coach': 'Bobby Petrino',
#   'currszn': '2006',
#   'games': 50,
#   'left_censor': False,
#   'losses': 9,
#   'max_year': '06',
#   'min_year': '03',
#   'right_censor': False,
#   'seasons': 4,
#   'slug': 'petrino|03|06|louisville',
#   'team': 'louisville',
#   'wins': 41},
#  {'coach': 'Steve Kragthorpe',
#   'currszn': '2009',
#   'games': 36,
#   'left_censor': False,
#   'losses': 21,
#   'max_year': '09',
#   'min_year': '07',
#   'right_censor': False,
#   'seasons': 3,
#   'slug': 'kragthorpe|07|09|louisville',
#   'team': 'louisville',
#   'wins': 15},
#  {'coach': 'Charlie Strong',
#   'currszn': '2013',
#   'games': 52,
#   'left_censor': False,
#   'losses': 15,
#   'max_year': '13',
#   'min_year': '10',
#   'right_censor': False,
#   'seasons': 4,
#   'slug': 'strong|10|13|louisville',
#   'team': 'louisville',
#   'wins': 37},
#  {'coach': 'Bobby Petrino',
#   'currszn': '2016',
#   'games': 39,
#   'left_censor': False,
#   'losses': 13,
#   'max_year': '16',
#   'min_year': '14',
#   'right_censor': True,
#   'seasons': 3,
#   'slug': 'petrino|14|16|louisville',
#   'team': 'louisville',
#   'wins': 26},
#  {'coach': 'Bobby Petrino',
#   'currszn': '2016',
#   'games': 39,
#   'left_censor': False,
#   'losses': 13,
#   'max_year': '16',
#   'min_year': '14',
#   'right_censor': True,
#   'seasons': 3,
#   'slug': 'petrino|14|16|louisville',
#   'team': 'louisville',
#   'wins': 26},
#  {'coach': 'Ron Vanderlinden',
#   'currszn': '2000',
#   'games': 11,
#   'left_censor': True,
#   'losses': 6,
#   'max_year': '',
#   'min_year': '00',
#   'right_censor': False,
#   'seasons': 1,
#   'slug': 'vanderlinden|00||maryland',
#   'team': 'maryland',
#   'wins': 5},
#  {'coach': 'Ralph Friedgen',
#   'currszn': '2010',
#   'games': 124,
#   'left_censor': False,
#   'losses': 49,
#   'max_year': '10',
#   'min_year': '01',
#   'right_censor': False,
#   'seasons': 10,
#   'slug': 'friedgen|01|10|maryland',
#   'team': 'maryland',
#   'wins': 75},
#  {'coach': 'Randy Edsall',
#   'currszn': '2015',
#   'games': 56,
#   'left_censor': False,
#   'losses': 34,
#   'max_year': '15',
#   'min_year': '11',
#   'right_censor': False,
#   'seasons': 5,
#   'slug': 'edsall|11|15|maryland',
#   'team': 'maryland',
#   'wins': 22},
#  {'coach': 'Mike Locksley',
#   'currszn': '2015',
#   'games': 6,
#   'left_censor': False,
#   'losses': 5,
#   'max_year': '',
#   'min_year': '15',
#   'right_censor': False,
#   'seasons': 1,
#   'slug': 'locksley|15||maryland',
#   'team': 'maryland',
#   'wins': 1},
#  {'coach': 'D.J. Durkin',
#   'currszn': '2016',
#   'games': 13,
#   'left_censor': False,
#   'losses': 7,
#   'max_year': '16',
#   'min_year': '16',
#   'right_censor': True,
#   'seasons': 1,
#   'slug': 'durkin|16|16|maryland',
#   'team': 'maryland',
#   'wins': 6},
#  {'coach': 'D.J. Durkin',
#   'currszn': '2016',
#   'games': 13,
#   'left_censor': False,
#   'losses': 7,
#   'max_year': '16',
#   'min_year': '16',
#   'right_censor': True,
#   'seasons': 1,
#   'slug': 'durkin|16|16|maryland',
#   'team': 'maryland',
#   'wins': 6},
#  {'coach': 'Butch Davis',
#   'currszn': '2000',
#   'games': 11,
#   'left_censor': True,
#   'losses': 1,
#   'max_year': '',
#   'min_year': '00',
#   'right_censor': False,
#   'seasons': 1,
#   'slug': 'davis|00||miami-fl',
#   'team': 'miami-fl',
#   'wins': 10},
#  {'coach': 'Larry Coker',
#   'currszn': '2006',
#   'games': 74,
#   'left_censor': False,
#   'losses': 15,
#   'max_year': '06',
#   'min_year': '01',
#   'right_censor': False,
#   'seasons': 6,
#   'slug': 'coker|01|06|miami-fl',
#   'team': 'miami-fl',
#   'wins': 59},
#  {'coach': 'Randy Shannon',
#   'currszn': '2010',
#   'games': 50,
#   'left_censor': False,
#   'losses': 22,
#   'max_year': '10',
#   'min_year': '07',
#   'right_censor': False,
#   'seasons': 4,
#   'slug': 'shannon|07|10|miami-fl',
#   'team': 'miami-fl',
#   'wins': 28},
#  {'coach': 'Jeff Stoutland',
#   'currszn': '2010',
#   'games': 1,
#   'left_censor': False,
#   'losses': 1,
#   'max_year': '',
#   'min_year': '10',
#   'right_censor': False,
#   'seasons': 1,
#   'slug': 'stoutland|10||miami-fl',
#   'team': 'miami-fl',
#   'wins': 0},
#  {'coach': 'Al Golden',
#   'currszn': '2015',
#   'games': 57,
#   'left_censor': False,
#   'losses': 25,
#   'max_year': '15',
#   'min_year': '11',
#   'right_censor': False,
#   'seasons': 5,
#   'slug': 'golden|11|15|miami-fl',
#   'team': 'miami-fl',
#   'wins': 32},
#  {'coach': 'Larry Scott',
#   'currszn': '2015',
#   'games': 6,
#   'left_censor': False,
#   'losses': 2,
#   'max_year': '',
#   'min_year': '15',
#   'right_censor': False,
#   'seasons': 1,
#   'slug': 'scott|15||miami-fl',
#   'team': 'miami-fl',
#   'wins': 4},
#  {'coach': 'Mark Richt',
#   'currszn': '2016',
#   'games': 13,
#   'left_censor': False,
#   'losses': 4,
#   'max_year': '16',
#   'min_year': '16',
#   'right_censor': True,
#   'seasons': 1,
#   'slug': 'richt|16|16|miami-fl',
#   'team': 'miami-fl',
#   'wins': 9},
#  {'coach': 'Mark Richt',
#   'currszn': '2016',
#   'games': 13,
#   'left_censor': False,
#   'losses': 4,
#   'max_year': '16',
#   'min_year': '16',
#   'right_censor': True,
#   'seasons': 1,
#   'slug': 'richt|16|16|miami-fl',
#   'team': 'miami-fl',
#   'wins': 9},
#  {'coach': 'Lloyd Carr',
#   'currszn': '2007',
#   'games': 98,
#   'left_censor': True,
#   'losses': 26,
#   'max_year': '07',
#   'min_year': '00',
#   'right_censor': False,
#   'seasons': 8,
#   'slug': 'carr|00|07|michigan',
#   'team': 'michigan',
#   'wins': 72},
#  {'coach': 'Rich Rodriguez',
#   'currszn': '2010',
#   'games': 37,
#   'left_censor': False,
#   'losses': 22,
#   'max_year': '10',
#   'min_year': '08',
#   'right_censor': False,
#   'seasons': 3,
#   'slug': 'rodriguez|08|10|michigan',
#   'team': 'michigan',
#   'wins': 15},
#  {'coach': 'Brady Hoke',
#   'currszn': '2014',
#   'games': 51,
#   'left_censor': False,
#   'losses': 20,
#   'max_year': '14',
#   'min_year': '11',
#   'right_censor': False,
#   'seasons': 4,
#   'slug': 'hoke|11|14|michigan',
#   'team': 'michigan',
#   'wins': 31},
#  {'coach': 'Jim Harbaugh',
#   'currszn': '2016',
#   'games': 26,
#   'left_censor': False,
#   'losses': 6,
#   'max_year': '16',
#   'min_year': '15',
#   'right_censor': True,
#   'seasons': 2,
#   'slug': 'harbaugh|15|16|michigan',
#   'team': 'michigan',
#   'wins': 20},
#  {'coach': 'Jim Harbaugh',
#   'currszn': '2016',
#   'games': 26,
#   'left_censor': False,
#   'losses': 6,
#   'max_year': '16',
#   'min_year': '15',
#   'right_censor': True,
#   'seasons': 2,
#   'slug': 'harbaugh|15|16|michigan',
#   'team': 'michigan',
#   'wins': 20},
#  {'coach': 'Bobby Williams',
#   'currszn': '2002',
#   'games': 31,
#   'left_censor': True,
#   'losses': 17,
#   'max_year': '02',
#   'min_year': '00',
#   'right_censor': False,
#   'seasons': 3,
#   'slug': 'williams|00|02|michigan-state',
#   'team': 'michigan-state',
#   'wins': 14},
#  {'coach': 'Morris Watts',
#   'currszn': '2002',
#   'games': 3,
#   'left_censor': False,
#   'losses': 2,
#   'max_year': '',
#   'min_year': '02',
#   'right_censor': False,
#   'seasons': 1,
#   'slug': 'watts|02||michigan-state',
#   'team': 'michigan-state',
#   'wins': 1},
#  {'coach': 'John Smith',
#   'currszn': '2006',
#   'games': 48,
#   'left_censor': False,
#   'losses': 26,
#   'max_year': '06',
#   'min_year': '03',
#   'right_censor': False,
#   'seasons': 4,
#   'slug': 'smith|03|06|michigan-state',
#   'team': 'michigan-state',
#   'wins': 22},
#  {'coach': 'Mark Dantonio',
#   'currszn': '2016',
#   'games': 132,
#   'left_censor': False,
#   'losses': 42,
#   'max_year': '16',
#   'min_year': '07',
#   'right_censor': True,
#   'seasons': 10,
#   'slug': 'dantonio|07|16|michigan-state',
#   'team': 'michigan-state',
#   'wins': 90},
#  {'coach': 'Mark Dantonio',
#   'currszn': '2016',
#   'games': 132,
#   'left_censor': False,
#   'losses': 42,
#   'max_year': '16',
#   'min_year': '07',
#   'right_censor': True,
#   'seasons': 10,
#   'slug': 'dantonio|07|16|michigan-state',
#   'team': 'michigan-state',
#   'wins': 90},
#  {'coach': 'Glen Mason',
#   'currszn': '2006',
#   'games': 85,
#   'left_censor': True,
#   'losses': 37,
#   'max_year': '06',
#   'min_year': '00',
#   'right_censor': False,
#   'seasons': 7,
#   'slug': 'mason|00|06|minnesota',
#   'team': 'minnesota',
#   'wins': 48},
#  {'coach': 'Tim Brewster',
#   'currszn': '2010',
#   'games': 45,
#   'left_censor': False,
#   'losses': 30,
#   'max_year': '10',
#   'min_year': '07',
#   'right_censor': False,
#   'seasons': 4,
#   'slug': 'brewster|07|10|minnesota',
#   'team': 'minnesota',
#   'wins': 15},
#  {'coach': 'Jeff Horton',
#   'currszn': '2010',
#   'games': 5,
#   'left_censor': False,
#   'losses': 3,
#   'max_year': '',
#   'min_year': '10',
#   'right_censor': False,
#   'seasons': 1,
#   'slug': 'horton|10||minnesota',
#   'team': 'minnesota',
#   'wins': 2},
#  {'coach': 'Jerry Kill',
#   'currszn': '2015',
#   'games': 58,
#   'left_censor': False,
#   'losses': 29,
#   'max_year': '15',
#   'min_year': '11',
#   'right_censor': False,
#   'seasons': 5,
#   'slug': 'kill|11|15|minnesota',
#   'team': 'minnesota',
#   'wins': 29},
#  {'coach': 'Tracy Claeys',
#   'currszn': '2016',
#   'games': 19,
#   'left_censor': False,
#   'losses': 8,
#   'max_year': '16',
#   'min_year': '15',
#   'right_censor': True,
#   'seasons': 2,
#   'slug': 'claeys|15|16|minnesota',
#   'team': 'minnesota',
#   'wins': 11},
#  {'coach': 'Tracy Claeys',
#   'currszn': '2016',
#   'games': 19,
#   'left_censor': False,
#   'losses': 8,
#   'max_year': '16',
#   'min_year': '15',
#   'right_censor': True,
#   'seasons': 2,
#   'slug': 'claeys|15|16|minnesota',
#   'team': 'minnesota',
#   'wins': 11},
#  {'coach': 'David Cutcliffe',
#   'currszn': '2004',
#   'games': 59,
#   'left_censor': True,
#   'losses': 24,
#   'max_year': '04',
#   'min_year': '00',
#   'right_censor': False,
#   'seasons': 5,
#   'slug': 'cutcliffe|00|04|mississippi',
#   'team': 'mississippi',
#   'wins': 35},
#  {'coach': 'Ed Orgeron',
#   'currszn': '2007',
#   'games': 35,
#   'left_censor': False,
#   'losses': 25,
#   'max_year': '07',
#   'min_year': '05',
#   'right_censor': False,
#   'seasons': 3,
#   'slug': 'orgeron|05|07|mississippi',
#   'team': 'mississippi',
#   'wins': 10},
#  {'coach': 'Houston Nutt',
#   'currszn': '2011',
#   'games': 50,
#   'left_censor': False,
#   'losses': 26,
#   'max_year': '11',
#   'min_year': '08',
#   'right_censor': False,
#   'seasons': 4,
#   'slug': 'nutt|08|11|mississippi',
#   'team': 'mississippi',
#   'wins': 24},
#  {'coach': 'Hugh Freeze',
#   'currszn': '2016',
#   'games': 64,
#   'left_censor': False,
#   'losses': 25,
#   'max_year': '16',
#   'min_year': '12',
#   'right_censor': True,
#   'seasons': 5,
#   'slug': 'freeze|12|16|mississippi',
#   'team': 'mississippi',
#   'wins': 39},
#  {'coach': 'Hugh Freeze',
#   'currszn': '2016',
#   'games': 64,
#   'left_censor': False,
#   'losses': 25,
#   'max_year': '16',
#   'min_year': '12',
#   'right_censor': True,
#   'seasons': 5,
#   'slug': 'freeze|12|16|mississippi',
#   'team': 'mississippi',
#   'wins': 39},
#  {'coach': 'Jackie Sherrill',
#   'currszn': '2003',
#   'games': 46,
#   'left_censor': True,
#   'losses': 31,
#   'max_year': '03',
#   'min_year': '00',
#   'right_censor': False,
#   'seasons': 4,
#   'slug': 'sherrill|00|03|mississippi-state',
#   'team': 'mississippi-state',
#   'wins': 15},
#  {'coach': 'Sylvester Croom',
#   'currszn': '2008',
#   'games': 59,
#   'left_censor': False,
#   'losses': 38,
#   'max_year': '08',
#   'min_year': '04',
#   'right_censor': False,
#   'seasons': 5,
#   'slug': 'croom|04|08|mississippi-state',
#   'team': 'mississippi-state',
#   'wins': 21},
#  {'coach': 'Dan Mullen',
#   'currszn': '2016',
#   'games': 103,
#   'left_censor': False,
#   'losses': 42,
#   'max_year': '16',
#   'min_year': '09',
#   'right_censor': True,
#   'seasons': 8,
#   'slug': 'mullen|09|16|mississippi-state',
#   'team': 'mississippi-state',
#   'wins': 61},
#  {'coach': 'Dan Mullen',
#   'currszn': '2016',
#   'games': 103,
#   'left_censor': False,
#   'losses': 42,
#   'max_year': '16',
#   'min_year': '09',
#   'right_censor': True,
#   'seasons': 8,
#   'slug': 'mullen|09|16|mississippi-state',
#   'team': 'mississippi-state',
#   'wins': 61},
#  {'coach': 'Larry Smith',
#   'currszn': '2000',
#   'games': 11,
#   'left_censor': True,
#   'losses': 8,
#   'max_year': '',
#   'min_year': '00',
#   'right_censor': False,
#   'seasons': 1,
#   'slug': 'smith|00||missouri',
#   'team': 'missouri',
#   'wins': 3},
#  {'coach': 'Gary Pinkel',
#   'currszn': '2015',
#   'games': 191,
#   'left_censor': False,
#   'losses': 73,
#   'max_year': '15',
#   'min_year': '01',
#   'right_censor': False,
#   'seasons': 15,
#   'slug': 'pinkel|01|15|missouri',
#   'team': 'missouri',
#   'wins': 118},
#  {'coach': 'Barry Odom',
#   'currszn': '2016',
#   'games': 12,
#   'left_censor': False,
#   'losses': 8,
#   'max_year': '16',
#   'min_year': '16',
#   'right_censor': True,
#   'seasons': 1,
#   'slug': 'odom|16|16|missouri',
#   'team': 'missouri',
#   'wins': 4},
#  {'coach': 'Barry Odom',
#   'currszn': '2016',
#   'games': 12,
#   'left_censor': False,
#   'losses': 8,
#   'max_year': '16',
#   'min_year': '16',
#   'right_censor': True,
#   'seasons': 1,
#   'slug': 'odom|16|16|missouri',
#   'team': 'missouri',
#   'wins': 4},
#  {'coach': 'Frank Solich',
#   'currszn': '2003',
#   'games': 49,
#   'left_censor': True,
#   'losses': 13,
#   'max_year': '03',
#   'min_year': '00',
#   'right_censor': False,
#   'seasons': 4,
#   'slug': 'solich|00|03|nebraska',
#   'team': 'nebraska',
#   'wins': 36},
#  {'coach': 'Bo Pelini',
#   'currszn': '2003',
#   'games': 1,
#   'left_censor': False,
#   'losses': 0,
#   'max_year': '',
#   'min_year': '03',
#   'right_censor': False,
#   'seasons': 1,
#   'slug': 'pelini|03||nebraska',
#   'team': 'nebraska',
#   'wins': 1},
#  {'coach': 'Bill Callahan',
#   'currszn': '2007',
#   'games': 49,
#   'left_censor': False,
#   'losses': 22,
#   'max_year': '07',
#   'min_year': '04',
#   'right_censor': False,
#   'seasons': 4,
#   'slug': 'callahan|04|07|nebraska',
#   'team': 'nebraska',
#   'wins': 27},
#  {'coach': 'Bo Pelini',
#   'currszn': '2014',
#   'games': 93,
#   'left_censor': False,
#   'losses': 27,
#   'max_year': '14',
#   'min_year': '08',
#   'right_censor': False,
#   'seasons': 7,
#   'slug': 'pelini|08|14|nebraska',
#   'team': 'nebraska',
#   'wins': 66},
#  {'coach': 'Barney Cotton',
#   'currszn': '2014',
#   'games': 1,
#   'left_censor': False,
#   'losses': 1,
#   'max_year': '',
#   'min_year': '14',
#   'right_censor': False,
#   'seasons': 1,
#   'slug': 'cotton|14||nebraska',
#   'team': 'nebraska',
#   'wins': 0},
#  {'coach': 'Mike Riley',
#   'currszn': '2016',
#   'games': 26,
#   'left_censor': False,
#   'losses': 11,
#   'max_year': '16',
#   'min_year': '15',
#   'right_censor': True,
#   'seasons': 2,
#   'slug': 'riley|15|16|nebraska',
#   'team': 'nebraska',
#   'wins': 15},
#  {'coach': 'Mike Riley',
#   'currszn': '2016',
#   'games': 26,
#   'left_censor': False,
#   'losses': 11,
#   'max_year': '16',
#   'min_year': '15',
#   'right_censor': True,
#   'seasons': 2,
#   'slug': 'riley|15|16|nebraska',
#   'team': 'nebraska',
#   'wins': 15},
#  {'coach': 'Carl Torbush',
#   'currszn': '2000',
#   'games': 11,
#   'left_censor': True,
#   'losses': 5,
#   'max_year': '',
#   'min_year': '00',
#   'right_censor': False,
#   'seasons': 1,
#   'slug': 'torbush|00||north-carolina',
#   'team': 'north-carolina',
#   'wins': 6},
#  {'coach': 'John Bunting',
#   'currszn': '2006',
#   'games': 71,
#   'left_censor': False,
#   'losses': 45,
#   'max_year': '06',
#   'min_year': '01',
#   'right_censor': False,
#   'seasons': 6,
#   'slug': 'bunting|01|06|north-carolina',
#   'team': 'north-carolina',
#   'wins': 26},
#  {'coach': 'Butch Davis',
#   'currszn': '2010',
#   'games': 51,
#   'left_censor': False,
#   'losses': 23,
#   'max_year': '10',
#   'min_year': '07',
#   'right_censor': False,
#   'seasons': 4,
#   'slug': 'davis|07|10|north-carolina',
#   'team': 'north-carolina',
#   'wins': 28},
#  {'coach': 'Everett Withers',
#   'currszn': '2011',
#   'games': 13,
#   'left_censor': False,
#   'losses': 6,
#   'max_year': '',
#   'min_year': '11',
#   'right_censor': False,
#   'seasons': 1,
#   'slug': 'withers|11||north-carolina',
#   'team': 'north-carolina',
#   'wins': 7},
#  {'coach': 'Larry Fedora',
#   'currszn': '2016',
#   'games': 65,
#   'left_censor': False,
#   'losses': 25,
#   'max_year': '16',
#   'min_year': '12',
#   'right_censor': True,
#   'seasons': 5,
#   'slug': 'fedora|12|16|north-carolina',
#   'team': 'north-carolina',
#   'wins': 40},
#  {'coach': 'Larry Fedora',
#   'currszn': '2016',
#   'games': 65,
#   'left_censor': False,
#   'losses': 25,
#   'max_year': '16',
#   'min_year': '12',
#   'right_censor': True,
#   'seasons': 5,
#   'slug': 'fedora|12|16|north-carolina',
#   'team': 'north-carolina',
#   'wins': 40},
#  {'coach': 'Chuck Amato',
#   'currszn': '2006',
#   'games': 84,
#   'left_censor': True,
#   'losses': 36,
#   'max_year': '06',
#   'min_year': '00',
#   'right_censor': False,
#   'seasons': 7,
#   'slug': 'amato|00|06|north-carolina-state',
#   'team': 'north-carolina-state',
#   'wins': 48},
#  {'coach': "Tom O'Brien",
#   'currszn': '2012',
#   'games': 75,
#   'left_censor': False,
#   'losses': 35,
#   'max_year': '12',
#   'min_year': '07',
#   'right_censor': False,
#   'seasons': 6,
#   'slug': "o'brien|07|12|north-carolina-state",
#   'team': 'north-carolina-state',
#   'wins': 40},
#  {'coach': 'Dana Bible',
#   'currszn': '2012',
#   'games': 1,
#   'left_censor': False,
#   'losses': 1,
#   'max_year': '',
#   'min_year': '12',
#   'right_censor': False,
#   'seasons': 1,
#   'slug': 'bible|12||north-carolina-state',
#   'team': 'north-carolina-state',
#   'wins': 0},
#  {'coach': 'Dave Doeren',
#   'currszn': '2016',
#   'games': 51,
#   'left_censor': False,
#   'losses': 26,
#   'max_year': '16',
#   'min_year': '13',
#   'right_censor': True,
#   'seasons': 4,
#   'slug': 'doeren|13|16|north-carolina-state',
# ...
#   'min_year': '00',
#   'right_censor': False,
#   'seasons': 1,
#   'slug': 'franchione|00||texas-christian',
#   'team': 'texas-christian',
#   'wins': 10},
#  {'coach': 'Gary Patterson',
#   'currszn': '2016',
#   'games': 201,
#   'left_censor': False,
#   'losses': 52,
#   'max_year': '16',
#   'min_year': '01',
#   'right_censor': True,
#   'seasons': 16,
#   'slug': 'patterson|01|16|texas-christian',
#   'team': 'texas-christian',
#   'wins': 149},
#  {'coach': 'Gary Patterson',
#   'currszn': '2016',
#   'games': 201,
#   'left_censor': False,
#   'losses': 52,
#   'max_year': '16',
#   'min_year': '01',
#   'right_censor': True,
#   'seasons': 16,
#   'slug': 'patterson|01|16|texas-christian',
#   'team': 'texas-christian',
#   'wins': 149},
#  {'coach': 'Mike Leach',
#   'currszn': '2009',
#   'games': 125,
#   'left_censor': True,
#   'losses': 41,
#   'max_year': '09',
#   'min_year': '00',
#   'right_censor': False,
#   'seasons': 10,
#   'slug': 'leach|00|09|texas-tech',
#   'team': 'texas-tech',
#   'wins': 84},
#  {'coach': 'Ruffin McNeill',
#   'currszn': '2009',
#   'games': 1,
#   'left_censor': False,
#   'losses': 0,
#   'max_year': '',
#   'min_year': '09',
#   'right_censor': False,
#   'seasons': 1,
#   'slug': 'mcneill|09||texas-tech',
#   'team': 'texas-tech',
#   'wins': 1},
#  {'coach': 'Tommy Tuberville',
#   'currszn': '2012',
#   'games': 37,
#   'left_censor': False,
#   'losses': 17,
#   'max_year': '12',
#   'min_year': '10',
#   'right_censor': False,
#   'seasons': 3,
#   'slug': 'tuberville|10|12|texas-tech',
#   'team': 'texas-tech',
#   'wins': 20},
#  {'coach': 'Chris Thomsen',
#   'currszn': '2012',
#   'games': 1,
#   'left_censor': False,
#   'losses': 0,
#   'max_year': '',
#   'min_year': '12',
#   'right_censor': False,
#   'seasons': 1,
#   'slug': 'thomsen|12||texas-tech',
#   'team': 'texas-tech',
#   'wins': 1},
#  {'coach': 'Kliff Kingsbury',
#   'currszn': '2016',
#   'games': 50,
#   'left_censor': False,
#   'losses': 26,
#   'max_year': '16',
#   'min_year': '13',
#   'right_censor': True,
#   'seasons': 4,
#   'slug': 'kingsbury|13|16|texas-tech',
#   'team': 'texas-tech',
#   'wins': 24},
#  {'coach': 'Kliff Kingsbury',
#   'currszn': '2016',
#   'games': 50,
#   'left_censor': False,
#   'losses': 26,
#   'max_year': '16',
#   'min_year': '13',
#   'right_censor': True,
#   'seasons': 4,
#   'slug': 'kingsbury|13|16|texas-tech',
#   'team': 'texas-tech',
#   'wins': 24},
#  {'coach': 'Bob Toledo',
#   'currszn': '2002',
#   'games': 34,
#   'left_censor': True,
#   'losses': 14,
#   'max_year': '02',
#   'min_year': '00',
#   'right_censor': False,
#   'seasons': 3,
#   'slug': 'toledo|00|02|ucla',
#   'team': 'ucla',
#   'wins': 20},
#  {'coach': 'Ed Kezirian',
#   'currszn': '2002',
#   'games': 1,
#   'left_censor': False,
#   'losses': 0,
#   'max_year': '',
#   'min_year': '02',
#   'right_censor': False,
#   'seasons': 1,
#   'slug': 'kezirian|02||ucla',
#   'team': 'ucla',
#   'wins': 1},
#  {'coach': 'Karl Dorrell',
#   'currszn': '2007',
#   'games': 62,
#   'left_censor': False,
#   'losses': 27,
#   'max_year': '07',
#   'min_year': '03',
#   'right_censor': False,
#   'seasons': 5,
#   'slug': 'dorrell|03|07|ucla',
#   'team': 'ucla',
#   'wins': 35},
#  {'coach': 'DeWayne Walker',
#   'currszn': '2007',
#   'games': 1,
#   'left_censor': False,
#   'losses': 1,
#   'max_year': '',
#   'min_year': '07',
#   'right_censor': False,
#   'seasons': 1,
#   'slug': 'walker|07||ucla',
#   'team': 'ucla',
#   'wins': 0},
#  {'coach': 'Rick Neuheisel',
#   'currszn': '2011',
#   'games': 49,
#   'left_censor': False,
#   'losses': 28,
#   'max_year': '11',
#   'min_year': '08',
#   'right_censor': False,
#   'seasons': 4,
#   'slug': 'neuheisel|08|11|ucla',
#   'team': 'ucla',
#   'wins': 21},
#  {'coach': 'Mike Johnson',
#   'currszn': '2011',
#   'games': 2,
#   'left_censor': False,
#   'losses': 2,
#   'max_year': '',
#   'min_year': '11',
#   'right_censor': False,
#   'seasons': 1,
#   'slug': 'johnson|11||ucla',
#   'team': 'ucla',
#   'wins': 0},
#  {'coach': 'Jim Mora',
#   'currszn': '2016',
#   'games': 65,
#   'left_censor': False,
#   'losses': 24,
#   'max_year': '16',
#   'min_year': '12',
#   'right_censor': True,
#   'seasons': 5,
#   'slug': 'mora|12|16|ucla',
#   'team': 'ucla',
#   'wins': 41},
#  {'coach': 'Jim Mora',
#   'currszn': '2016',
#   'games': 65,
#   'left_censor': False,
#   'losses': 24,
#   'max_year': '16',
#   'min_year': '12',
#   'right_censor': True,
#   'seasons': 5,
#   'slug': 'mora|12|16|ucla',
#   'team': 'ucla',
#   'wins': 41},
#  {'coach': 'Ron McBride',
#   'currszn': '2002',
#   'games': 33,
#   'left_censor': True,
#   'losses': 17,
#   'max_year': '02',
#   'min_year': '00',
#   'right_censor': False,
#   'seasons': 3,
#   'slug': 'mcbride|00|02|utah',
#   'team': 'utah',
#   'wins': 16},
#  {'coach': 'Urban Meyer',
#   'currszn': '2004',
#   'games': 24,
#   'left_censor': False,
#   'losses': 2,
#   'max_year': '04',
#   'min_year': '03',
#   'right_censor': False,
#   'seasons': 2,
#   'slug': 'meyer|03|04|utah',
#   'team': 'utah',
#   'wins': 22},
#  {'coach': 'Kyle Whittingham',
#   'currszn': '2016',
#   'games': 153,
#   'left_censor': False,
#   'losses': 50,
#   'max_year': '16',
#   'min_year': '05',
#   'right_censor': True,
#   'seasons': 12,
#   'slug': 'whittingham|05|16|utah',
#   'team': 'utah',
#   'wins': 103},
#  {'coach': 'Kyle Whittingham',
#   'currszn': '2016',
#   'games': 153,
#   'left_censor': False,
#   'losses': 50,
#   'max_year': '16',
#   'min_year': '05',
#   'right_censor': True,
#   'seasons': 12,
#   'slug': 'whittingham|05|16|utah',
#   'team': 'utah',
#   'wins': 103},
#  {'coach': 'Woody Widenhofer',
#   'currszn': '2001',
#   'games': 22,
#   'left_censor': True,
#   'losses': 17,
#   'max_year': '01',
#   'min_year': '00',
#   'right_censor': False,
#   'seasons': 2,
#   'slug': 'widenhofer|00|01|vanderbilt',
#   'team': 'vanderbilt',
#   'wins': 5},
#  {'coach': 'Bobby Johnson',
#   'currszn': '2009',
#   'games': 95,
#   'left_censor': False,
#   'losses': 66,
#   'max_year': '09',
#   'min_year': '02',
#   'right_censor': False,
#   'seasons': 8,
#   'slug': 'johnson|02|09|vanderbilt',
#   'team': 'vanderbilt',
#   'wins': 29},
#  {'coach': 'Robbie Caldwell',
#   'currszn': '2010',
#   'games': 12,
#   'left_censor': False,
#   'losses': 10,
#   'max_year': '',
#   'min_year': '10',
#   'right_censor': False,
#   'seasons': 1,
#   'slug': 'caldwell|10||vanderbilt',
#   'team': 'vanderbilt',
#   'wins': 2},
#  {'coach': 'James Franklin',
#   'currszn': '2013',
#   'games': 39,
#   'left_censor': False,
#   'losses': 15,
#   'max_year': '13',
#   'min_year': '11',
#   'right_censor': False,
#   'seasons': 3,
#   'slug': 'franklin|11|13|vanderbilt',
#   'team': 'vanderbilt',
#   'wins': 24},
#  {'coach': 'Derek Mason',
#   'currszn': '2016',
#   'games': 37,
#   'left_censor': False,
#   'losses': 24,
#   'max_year': '16',
#   'min_year': '14',
#   'right_censor': True,
#   'seasons': 3,
#   'slug': 'mason|14|16|vanderbilt',
#   'team': 'vanderbilt',
#   'wins': 13},
#  {'coach': 'Derek Mason',
#   'currszn': '2016',
#   'games': 37,
#   'left_censor': False,
#   'losses': 24,
#   'max_year': '16',
#   'min_year': '14',
#   'right_censor': True,
#   'seasons': 3,
#   'slug': 'mason|14|16|vanderbilt',
#   'team': 'vanderbilt',
#   'wins': 13},
#  {'coach': 'George Welsh',
#   'currszn': '2000',
#   'games': 11,
#   'left_censor': True,
#   'losses': 5,
#   'max_year': '',
#   'min_year': '00',
#   'right_censor': False,
#   'seasons': 1,
#   'slug': 'welsh|00||virginia',
#   'team': 'virginia',
#   'wins': 6},
#  {'coach': 'Al Groh',
#   'currszn': '2009',
#   'games': 112,
#   'left_censor': False,
#   'losses': 53,
#   'max_year': '09',
#   'min_year': '01',
#   'right_censor': False,
#   'seasons': 9,
#   'slug': 'groh|01|09|virginia',
#   'team': 'virginia',
#   'wins': 59},
#  {'coach': 'Mike London',
#   'currszn': '2015',
#   'games': 73,
#   'left_censor': False,
#   'losses': 46,
#   'max_year': '15',
#   'min_year': '10',
#   'right_censor': False,
#   'seasons': 6,
#   'slug': 'london|10|15|virginia',
#   'team': 'virginia',
#   'wins': 27},
#  {'coach': 'Bronco Mendenhall',
#   'currszn': '2016',
#   'games': 12,
#   'left_censor': False,
#   'losses': 10,
#   'max_year': '16',
#   'min_year': '16',
#   'right_censor': True,
#   'seasons': 1,
#   'slug': 'mendenhall|16|16|virginia',
#   'team': 'virginia',
#   'wins': 2},
#  {'coach': 'Bronco Mendenhall',
#   'currszn': '2016',
#   'games': 12,
#   'left_censor': False,
#   'losses': 10,
#   'max_year': '16',
#   'min_year': '16',
#   'right_censor': True,
#   'seasons': 1,
#   'slug': 'mendenhall|16|16|virginia',
#   'team': 'virginia',
#   'wins': 2},
#  {'coach': 'Frank Beamer',
#   'currszn': '2015',
#   'games': 209,
#   'left_censor': True,
#   'losses': 60,
#   'max_year': '15',
#   'min_year': '00',
#   'right_censor': False,
#   'seasons': 16,
#   'slug': 'beamer|00|15|virginia-tech',
#   'team': 'virginia-tech',
#   'wins': 149},
#  {'coach': 'Justin Fuente',
#   'currszn': '2016',
#   'games': 14,
#   'left_censor': False,
#   'losses': 4,
#   'max_year': '16',
#   'min_year': '16',
#   'right_censor': True,
#   'seasons': 1,
#   'slug': 'fuente|16|16|virginia-tech',
#   'team': 'virginia-tech',
#   'wins': 10},
#  {'coach': 'Justin Fuente',
#   'currszn': '2016',
#   'games': 14,
#   'left_censor': False,
#   'losses': 4,
#   'max_year': '16',
#   'min_year': '16',
#   'right_censor': True,
#   'seasons': 1,
#   'slug': 'fuente|16|16|virginia-tech',
#   'team': 'virginia-tech',
#   'wins': 10},
#  {'coach': 'Jim Caldwell',
#   'currszn': '2000',
#   'games': 11,
#   'left_censor': True,
#   'losses': 9,
#   'max_year': '',
#   'min_year': '00',
#   'right_censor': False,
#   'seasons': 1,
#   'slug': 'caldwell|00||wake-forest',
#   'team': 'wake-forest',
#   'wins': 2},
#  {'coach': 'Jim Grobe',
#   'currszn': '2013',
#   'games': 159,
#   'left_censor': False,
#   'losses': 82,
#   'max_year': '13',
#   'min_year': '01',
#   'right_censor': False,
#   'seasons': 13,
#   'slug': 'grobe|01|13|wake-forest',
#   'team': 'wake-forest',
#   'wins': 77},
#  {'coach': 'Dave Clawson',
#   'currszn': '2016',
#   'games': 37,
#   'left_censor': False,
#   'losses': 24,
#   'max_year': '16',
#   'min_year': '14',
#   'right_censor': True,
#   'seasons': 3,
#   'slug': 'clawson|14|16|wake-forest',
#   'team': 'wake-forest',
#   'wins': 13},
#  {'coach': 'Dave Clawson',
#   'currszn': '2016',
#   'games': 37,
#   'left_censor': False,
#   'losses': 24,
#   'max_year': '16',
#   'min_year': '14',
#   'right_censor': True,
#   'seasons': 3,
#   'slug': 'clawson|14|16|wake-forest',
#   'team': 'wake-forest',
#   'wins': 13},
#  {'coach': 'Rick Neuheisel',
#   'currszn': '2002',
#   'games': 35,
#   'left_censor': True,
#   'losses': 10,
#   'max_year': '02',
#   'min_year': '00',
#   'right_censor': False,
#   'seasons': 3,
#   'slug': 'neuheisel|00|02|washington',
#   'team': 'washington',
#   'wins': 25},
#  {'coach': 'Keith Gilbertson',
#   'currszn': '2004',
#   'games': 23,
#   'left_censor': False,
#   'losses': 16,
#   'max_year': '04',
#   'min_year': '03',
#   'right_censor': False,
#   'seasons': 2,
#   'slug': 'gilbertson|03|04|washington',
#   'team': 'washington',
#   'wins': 7},
#  {'coach': 'Tyrone Willingham',
#   'currszn': '2008',
#   'games': 48,
#   'left_censor': False,
#   'losses': 37,
#   'max_year': '08',
#   'min_year': '05',
#   'right_censor': False,
#   'seasons': 4,
#   'slug': 'willingham|05|08|washington',
#   'team': 'washington',
#   'wins': 11},
#  {'coach': 'Steve Sarkisian',
#   'currszn': '2013',
#   'games': 63,
#   'left_censor': False,
#   'losses': 29,
#   'max_year': '13',
#   'min_year': '09',
#   'right_censor': False,
#   'seasons': 5,
#   'slug': 'sarkisian|09|13|washington',
#   'team': 'washington',
#   'wins': 34},
#  {'coach': 'Marques Tuiasosopo',
#   'currszn': '2013',
#   'games': 1,
#   'left_censor': False,
#   'losses': 0,
#   'max_year': '',
#   'min_year': '13',
#   'right_censor': False,
#   'seasons': 1,
#   'slug': 'tuiasosopo|13||washington',
#   'team': 'washington',
#   'wins': 1},
#  {'coach': 'Chris Petersen',
#   'currszn': '2016',
#   'games': 41,
#   'left_censor': False,
#   'losses': 14,
#   'max_year': '16',
#   'min_year': '14',
#   'right_censor': True,
#   'seasons': 3,
#   'slug': 'petersen|14|16|washington',
#   'team': 'washington',
#   'wins': 27},
#  {'coach': 'Chris Petersen',
#   'currszn': '2016',
#   'games': 41,
#   'left_censor': False,
#   'losses': 14,
#   'max_year': '16',
#   'min_year': '14',
#   'right_censor': True,
#   'seasons': 3,
#   'slug': 'petersen|14|16|washington',
#   'team': 'washington',
#   'wins': 27},
#  {'coach': 'Mike Price',
#   'currszn': '2002',
#   'games': 35,
#   'left_censor': True,
#   'losses': 12,
#   'max_year': '02',
#   'min_year': '00',
#   'right_censor': False,
#   'seasons': 3,
#   'slug': 'price|00|02|washington-state',
#   'team': 'washington-state',
#   'wins': 23},
#  {'coach': 'Bill Doba',
#   'currszn': '2007',
#   'games': 59,
#   'left_censor': False,
#   'losses': 29,
#   'max_year': '07',
#   'min_year': '03',
#   'right_censor': False,
#   'seasons': 5,
#   'slug': 'doba|03|07|washington-state',
#   'team': 'washington-state',
#   'wins': 30},
#  {'coach': 'Paul Wulff',
#   'currszn': '2011',
#   'games': 49,
#   'left_censor': False,
#   'losses': 40,
#   'max_year': '11',
#   'min_year': '08',
#   'right_censor': False,
#   'seasons': 4,
#   'slug': 'wulff|08|11|washington-state',
#   'team': 'washington-state',
#   'wins': 9},
#  {'coach': 'Mike Leach',
#   'currszn': '2016',
#   'games': 63,
#   'left_censor': False,
#   'losses': 34,
#   'max_year': '16',
#   'min_year': '12',
#   'right_censor': True,
#   'seasons': 5,
#   'slug': 'leach|12|16|washington-state',
#   'team': 'washington-state',
#   'wins': 29},
#  {'coach': 'Mike Leach',
#   'currszn': '2016',
#   'games': 63,
#   'left_censor': False,
#   'losses': 34,
#   'max_year': '16',
#   'min_year': '12',
#   'right_censor': True,
#   'seasons': 5,
#   'slug': 'leach|12|16|washington-state',
#   'team': 'washington-state',
#   'wins': 29},
#  {'coach': 'Don Nehlen',
#   'currszn': '2000',
#   'games': 11,
#   'left_censor': True,
#   'losses': 5,
#   'max_year': '',
#   'min_year': '00',
#   'right_censor': False,
#   'seasons': 1,
#   'slug': 'nehlen|00||west-virginia',
#   'team': 'west-virginia',
#   'wins': 6},
#  {'coach': 'Rich Rodriguez',
#   'currszn': '2007',
#   'games': 86,
#   'left_censor': False,
#   'losses': 26,
#   'max_year': '07',
#   'min_year': '01',
#   'right_censor': False,
#   'seasons': 7,
#   'slug': 'rodriguez|01|07|west-virginia',
#   'team': 'west-virginia',
#   'wins': 60},
#  {'coach': 'Bill Stewart',
#   'currszn': '2010',
#   'games': 40,
#   'left_censor': False,
#   'losses': 12,
#   'max_year': '10',
#   'min_year': '07',
#   'right_censor': False,
#   'seasons': 4,
#   'slug': 'stewart|07|10|west-virginia',
#   'team': 'west-virginia',
#   'wins': 28},
#  {'coach': 'Dana Holgorsen',
#   'currszn': '2016',
#   'games': 77,
#   'left_censor': False,
#   'losses': 31,
#   'max_year': '16',
#   'min_year': '11',
#   'right_censor': True,
#   'seasons': 6,
#   'slug': 'holgorsen|11|16|west-virginia',
#   'team': 'west-virginia',
#   'wins': 46},
#  {'coach': 'Dana Holgorsen',
#   'currszn': '2016',
#   'games': 77,
#   'left_censor': False,
#   'losses': 31,
#   'max_year': '16',
#   'min_year': '11',
#   'right_censor': True,
#   'seasons': 6,
#   'slug': 'holgorsen|11|16|west-virginia',
#   'team': 'west-virginia',
#   'wins': 46},
#  {'coach': 'Barry Alvarez',
#   'currszn': '2005',
#   'games': 76,
#   'left_censor': True,
#   'losses': 29,
#   'max_year': '05',
#   'min_year': '00',
#   'right_censor': False,
#   'seasons': 6,
#   'slug': 'alvarez|00|05|wisconsin',
#   'team': 'wisconsin',
#   'wins': 47},
#  {'coach': 'Bret Bielema',
#   'currszn': '2012',
#   'games': 92,
#   'left_censor': False,
#   'losses': 24,
#   'max_year': '12',
#   'min_year': '06',
#   'right_censor': False,
#   'seasons': 7,
#   'slug': 'bielema|06|12|wisconsin',
#   'team': 'wisconsin',
#   'wins': 68},
#  {'coach': 'Barry Alvarez',
#   'currszn': '2012',
#   'games': 1,
#   'left_censor': False,
#   'losses': 1,
#   'max_year': '',
#   'min_year': '12',
#   'right_censor': False,
#   'seasons': 1,
#   'slug': 'alvarez|12||wisconsin',
#   'team': 'wisconsin',
#   'wins': 0},
#  {'coach': 'Gary Andersen',
#   'currszn': '2014',
#   'games': 26,
#   'left_censor': False,
#   'losses': 7,
#   'max_year': '14',
#   'min_year': '13',
#   'right_censor': False,
#   'seasons': 2,
#   'slug': 'andersen|13|14|wisconsin',
#   'team': 'wisconsin',
#   'wins': 19},
#  {'coach': 'Barry Alvarez',
#   'currszn': '2014',
#   'games': 1,
#   'left_censor': False,
#   'losses': 0,
#   'max_year': '',
#   'min_year': '14',
#   'right_censor': False,
#   'seasons': 1,
#   'slug': 'alvarez|14||wisconsin',
#   'team': 'wisconsin',
#   'wins': 1},
#  {'coach': 'Paul Chryst',
#   'currszn': '2016',
#   'games': 27,
#   'left_censor': False,
#   'losses': 6,
#   'max_year': '16',
#   'min_year': '15',
#   'right_censor': True,
#   'seasons': 2,
#   'slug': 'chryst|15|16|wisconsin',
#   'team': 'wisconsin',
#   'wins': 21}]
